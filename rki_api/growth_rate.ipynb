# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/landkreise_timeseries.csv')
agg_data = data.groupby('Bundesland').sum()

# %%
agg_data
# Out:
#                         03-22-2020  03-23-2020  03-24-2020  03-25-2020  \
# Bundesland
# Baden-Württemberg             3807        3811        5348        6069
# Bayern                        3650        4892        5754        6558
# Berlin                        1024        1077        1220        1428
# Brandenburg                    274         288         343         429
# Bremen                         165         170         183         200
# Hamburg                        872         943        1043        1262
# Hessen                        1175        1347        1620        1754
# Mecklenburg-Vorpommern         172         172         199         218
# Niedersachsen                 1306        1483        1764        2140
# Nordrhein-Westfalen           3545        5615        6318        7197
# Rheinland-Pfalz               1053        1177        1370        1591
# Saarland                       187         200         337         403
# ...

# %%
agg_data = agg_data.append(agg_data.sum(), ignore_index=True)

# %%
diff_perc_data = agg_data.diff(axis=1)/agg_data*100

# %%
diff_data = agg_data.diff(axis=1)

# %%
timeseries = data.columns[2:]

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.barplot(y=diff_data.iloc[16], x=timeseries, palette="rocket", ax=ax)
ax.tick_params(labelrotation=45)
plt.show()
